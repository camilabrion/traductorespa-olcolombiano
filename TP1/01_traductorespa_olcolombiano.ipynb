# %% [markdown]
# <a href="https://colab.research.google.com/github/camilabrion/traductorespa-olcolombiano/blob/main/TP1/01_traductorespa_olcolombiano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# Definimos un diccionario de traducción para palabras específicas
traducciones_espanol_colombiano = {
    "parce": "tío",
    "chévere": "guay",
    "camellar": "trabajar",
    "carro": "coche",
    "lindo": "mono",
    "mona": "rubia",
    "mono": "rubio",
    "linda": "mona",
    "tinto": "cafe",
    "vino": "tinto",
    "torta": "pastel",
    "capullo": "brote de una planta",
    "(insulto fuerte)": "capullo",
    "polla": "ataque de risa prolongado",
    "miembro masculino": "polla",
    "bocadillo": "dulce de guayaba",
    "sandwich": "bocadillo",
    "chévere": "guay",
    "bacano": " que mola",
    "apartamento": " piso",
    "piso": " pavimento",
    "bacano": "mola",
    "parche": "quedada",
    "jartera": "fiesta",
    "pelar el cobre": "desnudarse",
    "chimba": "chulo",
    "paila": "lata",
    "peye": "pobre",
    "pupitrazo": "bofetada",
    "rumbear": "salir de fiesta",
    "parrandear": "juerguear",
    "guayabo": "resaca",
    "chamuyar": "ligar",
    "gringo": "extranjero",
    "chavo": "dinero",
    "güevón": "tonto",
    "joda": "molestia",
    "coger": "tomar",
    "pico": "beso",
    "bacán": "genial",
    "vaina": "cosa",
    "pelaos": "chicos",
    "berraco": "valiente",
    "chévere": "guay",
    "farra": "fiesta",
    "güiro": "bolsa",
    "guaro": "aguardiente",
    "buen parche": "buena compañía",
    "cucho": "viejo",
    "embolatado": "aburrido",
    "gamin": "vagabundo",
    "pisto": "dinero",
    "ruco": "viejo",
    "amarre": "ligue",
    "quilombo": "lío",
    "fiñe": "fea",
    "fresco": "descarado",
    "tirar los perros": "flirtear",
    "currambera": "trabajadora",
    "totuma": "calabaza",
    "marica": "maricón",
    "peluca": "peluquín",
    "hombre bala": "lanzador de cuchillos",
    "rato": "un tiempo",
    "culear": "tener sexo",
    "churro": "chico guapo",
    "arepa": "tortita de maíz",
    "pata": "pierna",
    "mamar gallo": "tomar el pelo",
    "candela": "fuego",
    "grillar": "asustar",
    "lora": "charla",
    "macanudo": "fantástico",
    "gringada": "tontería",
    "totumo": "calabaza",
    "vacan": "genial",
    "zorro": "astuto",
    "bajonazo": "pérdida",
    "baboso": "tonto",
    "plata": "dinero",
    "lana": "dinero",
    "verga": "pene",
    "usted es la verga": "usted es muy divertido",
    "plomazo": "disparo",
    "pargo": "pescado",
    "berraco": "valiente",
    "marrano": "cerdo",
    "chacharear": "rebuscar",
    "piquete": "discusión",
    "machetear": "atacar",
    "rebusque": "busca",
    "guachafita": "revuelo",
    "godo": "persona adinerada",
    "acordarse": "recordar",
    "bollo": "pastelito",
    "chimbo": "malo",
    "empelota": "desnudo",
    "chuchaqui": "resaca",
    "chismoso": "cotilla",
    "pega": "trabajo",
    "zarrapastroso": "sucio",
    "guineo": "plátano",
    "parlante": "altavoz",
    "guayabo": "resaca",
    "jamear": "comer",
    "peye": "pobre",
    "pirao": "loco",
    "chévere": "guay",
    "bacano": "mola",
    "rumbear": "salir de fiesta",
    "parrandear": "juerguear",
    "guayabo": "resaca",
    "chamuyar": "ligar",
    "gringo": "extranjero",
    "chavo": "dinero",
    "güevón": "tonto",
    "joda": "molestia",
    "tranquilamente": "tranquilamente",
    "coger": "tomar",
    "pico": "beso",
    "bacán": "genial",
    "pirobo": "golfo",
    "vaina": "cosa",
    "pelaos": "chicos",
    "berraco": "valiente",
    "farra": "fiesta",
    "güiro": "bolsa",
    "guaro": "aguardiente",
    "tinto": "café",
    "buen parche": "buena compañía",
    "cucho": "viejo",
    "embolatado": "aburrido",
    "gamin": "vagabundo",
    "pisto": "dinero",
    "ruco": "viejo",
    "amarre": "ligue",
    "quilombo": "lío",
    "fiñe": "fea",
    # Agrega más palabras y sus traducciones según lo necesites
}

traducciones_espanol_mexicano = {
    "parce": "cuate",
    "chévere": "padre",
    "camellar": "chambear",
    "carro": "auto",
    "lindo": "bonito",
    "mona": "rubia",
    "mono": "rubio",
    "linda": "bonita",
    "tinto": "café",
    "vino": "tinto",
    "torta": "pastel",
    "capullo": "capullo",
    "(insulto fuerte)": "tonto",
    "polla": "risa contagiosa",
    "miembro masculino": "pene",
    "bocadillo": "dulce",
    "sandwich": "sándwich",
    "bacano": "chido",
    "apartamento": "departamento",
    "piso": "pavimento",
    "parche": "reunión",
    "jartera": "fiesta",
    "pelar el cobre": "desnudarse",
    "chimba": "padre",
    "paila": "mala suerte",
    "peye": "pobre",
    "pupitrazo": "golpazo",
    "rumbear": "salir de fiesta",
    "parrandear": "fiestar",
    "guayabo": "cruda",
    "chamuyar": "coquetear",
    "gringo": "extranjero",
    "chavo": "dinero",
    "güevón": "tonto",
    "joda": "problema",
    "coger": "agarrar",
    "pico": "beso",
    "bacán": "genial",
    "vaina": "cosa",
    "pelaos": "chavos",
    "berraco": "valiente",
    "farra": "fiesta",
    "güiro": "bolsa",
    "guaro": "aguardiente",
    "buen parche": "buena compañía",
    "cucho": "viejo",
    "embolatado": "aburrido",
    "gamin": "vagabundo",
    "pisto": "dinero",
    "ruco": "viejo",
    "amarre": "ligue",
    "quilombo": "lío",
    "fiñe": "fea",
    "fresco": "descarado",
    "tirar los perros": "ligar",
    "currambera": "trabajadora",
    "totuma": "calabaza",
    "marica": "maricón",
    "peluca": "peluquín",
    "hombre bala": "lanzador de cuchillos",
    "rato": "tiempo",
    "culear": "tener sexo",
    "churro": "chico guapo",
    "arepa": "tortita de maíz",
    "pata": "pierna",
    "mamar gallo": "tomar el pelo",
    "candela": "fuego",
    "grillar": "asustar",
    "lora": "charla",
    "macanudo": "padre",
    "gringada": "tontería",
    "totumo": "calabaza",
    "vacan": "chido",
    "zorro": "astuto",
    "bajonazo": "golpe fuerte",
    "baboso": "tonto",
    "plata": "dinero",
    "lana": "dinero",
    "verga": "pene",
    "usted es la verga": "eres muy divertido",
    "plomazo": "disparo",
    "pargo": "pez",
    "berraco": "valiente",
    "marrano": "cerdo",
    "chacharear": "rebuscar",
    "piquete": "protesta",
    "machetear": "atacar",
    "rebusque": "búsqueda",
    "guachafita": "alboroto",
    "godo": "persona adinerada",
    "acordarse": "recordar",
    "bollo": "pastelito",
    "chimbo": "malo",
    "empelota": "desnudo",
    "chuchaqui": "cruda",
    "chismoso": "cotilla",
    "pega": "trabajo",
    "zarrapastroso": "sucio",
    "guineo": "plátano",
    "parlante": "altavoz",
    "guayabo": "cruda",
    "jamear": "comer",
    "peye": "pobre",
    "pirao": "loco",
    # Agrega más palabras y sus traducciones según lo necesites
}

traducciones_espanol_argentino = {
    "parce": "pibe",
    "chévere": "copado",
    "camellar": "laburar",
    "carro": "auto",
    "lindo": "lindo",
    "mona": "rubia",
    "mono": "rubio",
    "linda": "linda",
    "tinto": "café",
    "vino": "vino",
    "torta": "torta",
    "capullo": "pelotudo",
    "(insulto fuerte)": "pelotudo",
    "polla": "risa contagiosa",
    "miembro masculino": "pene",
    "bocadillo": "dulce",
    "sandwich": "sándwich",
    "bacano": "copado",
    "apartamento": "departamento",
    "piso": "pavimento",
    "parche": "reunión",
    "jartera": "fiesta",
    "pelar el cobre": "desnudarse",
    "chimba": "genial",
    "paila": "mala suerte",
    "peye": "pobre",
    "pupitrazo": "piñazo",
    "rumbear": "salir de fiesta",
    "parrandear": "fiestear",
    "guayabo": "resaca",
    "chamuyar": "coquetear",
    "gringo": "extranjero",
    "chavo": "plata",
    "güevón": "boludo",
    "joda": "quilombo",
    "coger": "agarrar",
    "pico": "beso",
    "bacán": "genial",
    "vaina": "cosa",
    "pelaos": "pibes",
    "berraco": "valiente",
    "farra": "fiesta",
    "güiro": "bolsa",
    "guaro": "fernet",
    "buen parche": "buena compañía",
    "cucho": "viejo",
    "embolatado": "aburrido",
    "gamin": "pibe de la calle",
    "pisto": "plata",
    "ruco": "viejo",
    "amarre": "levante",
    "quilombo": "lío",
    "fiñe": "fea",
    "fresco": "canchero",
    "tirar los perros": "levantar",
    "currambera": "laburante",
    "totuma": "mate",
    "marica": "maricón",
    "peluca": "peluquín",
    "hombre bala": "lanzador de cuchillos",
    "rato": "un tiempo",
    "culear": "tener sexo",
    "churro": "pibe lindo",
    "arepa": "tortita",
    "pata": "pata",
    "mamar gallo": "tomar el pelo",
    "candela": "fuego",
    "grillar": "asustar",
    "lora": "charla",
    "macanudo": "copado",
    "gringada": "boludez",
    "totumo": "calabaza",
    "vacan": "copado",
    "zorro": "vivo",
    "bajonazo": "golpe",
    "baboso": "boludo",
    "plata": "plata",
    "lana": "plata",
    "verga": "pene",
    "usted es la verga": "sos muy divertido",
    "plomazo": "balazo",
    "pargo": "pescado",
    "berraco": "valiente",
    "marrano": "cerdo",
    "chacharear": "curiosear",
    "piquete": "protesta",
    "machetear": "atacar",
    "rebusque": "búsqueda",
    "guachafita": "revuelo",
    "godo": "persona adinerada",
    "acordarse": "acordarse",
    "bollo": "pastelito",
    "chimbo": "malo",
    "empelota": "desnudo",
    "chuchaqui": "resaca",
    "chismoso": "chismoso",
    "pega": "laburo",
    "zarrapastroso": "sucio",
    "guineo": "banana",
    "parlante": "parlante",
    "guayabo": "resaca",
    "jamear": "comer",
    "peye": "pobre",
    "pirao": "loco",

    # Agrega más palabras y sus traducciones según lo necesites
}

import re

# Definimos un diccionario de traducción para palabras específicas
traducciones_colombiano = {
    "parce": "corillo",
    "chévere": "chévere",
    "camellar": "trabajar",
    "carro": "auto",
    "lindo": "bello",
    "mona": "rubia",
    "mono": "rubio",
    "linda": "bella",
    "tinto": "café",
    "vino": "vino",
    "torta": "pastel",
    "capullo": "capullo",
    "(insulto fuerte)": "tonto",
    "polla": "risa descontrolada",
    "miembro masculino": "pene",
    "bocadillo": "dulce de guayaba",
    "sandwich": "sándwich",
    "bacano": "chévere",
    "apartamento": "apartamento",
    "piso": "pavimento",
    "parche": "juma",
    "jartera": "rumbón",
    "pelar el cobre": "desnudarse",
    "chimba": "genial",
    "paila": "mala suerte",
    "peye": "jama",
    "pupitrazo": "trancazo",
    "rumbear": "irse de parranda",
    "parrandear": "parrandear",
    "guayabo": "resaca",
    "chamuyar": "ligar",
    "gringo": "extranjero",
    "chavo": "plata",
    "güevón": "boludo",
    "joda": "problema",
    "coger": "agarrar",
    "pico": "beso",
    "bacán": "genial",
    "vaina": "cosa",
    "pelaos": "pelaos",
    "berraco": "valiente",
    "farra": "farra",
    "güiro": "cartera",
    "guaro": "ron",
    "buen parche": "buen parche",
    "cucho": "viejo",
    "embolatado": "embolatado",
    "gamin": "vagabundo",
    "pisto": "plata",
    "ruco": "ruco",
    "amarre": "ligue",
    "quilombo": "quilombo",
    "fiñe": "fea",
    "fresco": "fresco",
    "tirar los perros": "tirar los perros",
    "currambera": "currambera",
    "totuma": "totuma",
    "marica": "maricón",
    "peluca": "peluca",
    "hombre bala": "hombre bala",
    "rato": "rato",
    "culear": "culear",
    "churro": "churro",
    "arepa": "arepa",
    "pata": "pata",
    "mamar gallo": "tomar el pelo",
    "candela": "fuego",
    "grillar": "asustar",
    "lora": "lora",
    "macanudo": "macanudo",
    "gringada": "gringada",
    "totumo": "totumo",
    "vacan": "chévere",
    "zorro": "listo",
    "bajonazo": "golpe fuerte",
    "baboso": "boludo",
    "plata": "plata",
    "lana": "lana",
    "verga": "verga",
    "usted es la verga": "usted es la bomba",
    "plomazo": "plomazo",
    "pargo": "pargo",
    "berraco": "valiente",
    "marrano": "marrano",
    "chacharear": "chacharear",
    "piquete": "piquete",
    "machetear": "machetear",
    "rebusque": "rebusque",
    "guachafita": "guachafita",
    "godo": "godo",
    "acordarse": "acordarse",
    "bollo": "bollo",
    "chimbo": "chimbo",
    "empelota": "empelota",
    "chuchaqui": "chuchaqui",
    "chismoso": "chismoso",
    "pega": "pega",
    "zarrapastroso": "zarrapastroso",
    "guineo": "guineo",
    "parlante": "parlante",
    "guayabo": "guayabo"
}

# Función para traducir una oración a español de España
def traducir_colombiano_a_espanol(texto):
    for palabra_colombiana, palabra_espanola in traducciones_espanol_colombiano.items():
        texto = re.sub(rf'\b{palabra_colombiana}\b', palabra_espanola, texto)
    return texto

# Función para traducir una oración a español de México
def traducir_colombiano_a_mexicano(texto):
    for palabra_colombiana, palabra_mexicana in traducciones_espanol_mexicano.items():
        texto = re.sub(rf'\b{palabra_colombiana}\b', palabra_mexicana, texto)
    return texto

# Función para traducir una oración a español de Argentina
def traducir_colombiano_a_argentino(texto):
    for palabra_colombiana, palabra_argentina in traducciones_espanol_argentino.items():
        texto = re.sub(rf'\b{palabra_colombiana}\b', palabra_argentina, texto)
    return texto

def traducir_colombiano_a_espanol_puerto_rico(texto):
    for palabra_colombiana, palabra_puerto_rico in traducciones_colombiano.items():
        texto = re.sub(rf'\b{palabra_colombiana}\b', palabra_puerto_rico, texto)
    return texto

# Ingresa la oración en español colombiano
texto_colombiano = "parce, hoy en la madrugada me toco ir a camellar todo el dia, luego en la tarde el carro se me daño, pero vi a una mona muy linda, asi que le invite un tinto con torta, estuvo muy chévere."

# Traduce el texto a español de España
texto_espanol = traducir_colombiano_a_espanol(texto_colombiano)

# Traduce el texto a español de México
texto_mexicano = traducir_colombiano_a_mexicano(texto_colombiano)

# Traduce el texto a español de Argentina
texto_argentino = traducir_colombiano_a_argentino(texto_colombiano)

# Traduce el texto al español de Puerto Rico
texto_puerto_rico = traducir_colombiano_a_espanol_puerto_rico(texto_colombiano)

print("Texto en español colombiano: ", texto_colombiano)
print("Texto en español de España: ", texto_espanol)
print("Texto en español de México: ", texto_mexicano)
print("Texto en español de Argentina: ", texto_argentino)
print("Texto en español de Puerto Rico:", texto_puerto_rico)
# Out:
# Texto en español colombiano:  parce, hoy en la madrugada me toco ir a camellar todo el dia, luego en la tarde el carro se me daño, pero vi a una mona muy linda, asi que le invite un tinto con torta, estuvo muy chévere.
# Texto en español de España:  tío, hoy en la madrugada me toco ir a trabajar todo el dia, luego en la tarde el coche se me daño, pero vi a una rubia muy mona, asi que le invite un café con pastel, estuvo muy guay.
# Texto en español de México:  cuate, hoy en la madrugada me toco ir a chambear todo el dia, luego en la tarde el auto se me daño, pero vi a una rubia muy bonita, asi que le invite un café con pastel, estuvo muy padre.
# Texto en español de Argentina:  pibe, hoy en la madrugada me toco ir a laburar todo el dia, luego en la tarde el auto se me daño, pero vi a una rubia muy linda, asi que le invite un café con torta, estuvo muy copado.
# ...
